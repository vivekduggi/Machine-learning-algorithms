# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq

my_url = 'https://www.flipkart.com/search?q=iphone%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()
page_soup = soup(page_html, "html.parser")

containers = page_soup.findAll("div", {"class": "_3O0U0u"} )

print(len(containers))
# Out:
# 24

# %%
print(soup.prettify(containers[0]))
# Out:
# <div class="_3O0U0u">
#  <div data-id="MOBETM9FZWW5UEZG" style="width:100%">
#   <div class="_1UoZlX">
#    <a class="_31qSD5" href="/apple-iphone-se-space-grey-32-gb/p/itmetm9fypda5rfs?pid=MOBETM9FZWW5UEZG&amp;srno=s_1_1&amp;otracker=search&amp;lid=LSTMOBETM9FZWW5UEZGJKPO31&amp;fm=organic&amp;iid=a0daafc9-12b6-48d8-a3b9-8e9c8b44f670.MOBETM9FZWW5UEZG.SEARCH&amp;qH=4673a7c42221208f" rel="noopener noreferrer" target="_blank">
#     <div class="_3RW86r">
#      ON OFFER
#     </div>
#     <div class="_3SQWE6">
#      <div class="_1OCn9C">
#       <div>
#        <div class="_3BTv9X" style="height:200px;width:200px">
#         <img alt="Apple iPhone SE (Space Grey, 32 GB)" class="_1Nyybr" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg"/>
#        </div>
#       </div>
#      </div>
#      <div class="_2lesQu">
#       <div class="_1O_CiZ">
#        <span class="_1iHA1p">
#         <div class="_2kFyHg">
#          <label>
#           <input class="_3uUUD5" readonly="" type="checkbox"/>
#           <div class="_1p7h2j">
#           </div>
#          </label>
#         </div>
#        </span>
#        <label class="_10TB-Q">
#         <span>
#          Add to Compare
#         </span>
#        </label>
#       </div>
#      </div>
#      <div class="_3gDSOa _32A6AP">
#       <div class="DsQ2eg">
#        <svg class="_2oLiqr" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg">
#         <path class="_35Y7Yo" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="evenodd" opacity=".9" stroke="#FFF">
#         </path>
#        </svg>
#       </div>
#      </div>
#     </div>
#     <div class="_1-2Iqu row">
#      <div class="col col-7-12">
#       <div class="_3wU53n">
#        Apple iPhone SE (Space Grey, 32 GB)
#       </div>
#       <div class="niH0FQ">
#        <span class="_2_KrJI" id="productRating_LSTMOBETM9FZWW5UEZGJKPO31_MOBETM9FZWW5UEZG_">
#         <div class="hGSR34 _2beYZw">
#          4.4
#          <!-- -->
#          ★
#         </div>
#        </span>
#        <span class="_38sUEc">
#         <span>
#          <span>
#           44,107 Ratings
#          </span>
#          <span class="_1VpSqZ">
#           &amp;
#          </span>
#          <span>
#           6,495 Reviews
#          </span>
#         </span>
#        </span>
#       </div>
#       <div class="_3ULzGw">
#        <ul class="vFw0gD">
#         <li class="tVe95H">
#          32 GB ROM |
#         </li>
#         <li class="tVe95H">
#          10.16 cm (4 inch) Retina Display
#         </li>
#         <li class="tVe95H">
#          12MP Rear Camera | 1.2MP Front Camera
#         </li>
#         <li class="tVe95H">
#          Li-Ion Battery
#         </li>
#         <li class="tVe95H">
#          Apple A9 64-bit processor and Embedded M9 Motion Co-processor
#         </li>
#         <li class="tVe95H">
#          Brand Warranty of 1 Year
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col col-5-12 _2o7WAb">
#       <div class="_6BWGkk">
#        <div class="_1uv9Cb">
#         <div class="_1vC4OE _2rQ-NK">
#          ₹18,999
#         </div>
#         <div class="_3auQ3N _2GcJzG">
#          ₹
#          <!-- -->
#          26,000
#         </div>
#         <div class="VGWI6T">
#          <span>
#           26% off
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="_3n6o0t">
#        <img height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/>
#       </div>
#       <div class="_3gVem9">
#        <span>
#         Up to
#         <span class="_2xjzPG">
#          ₹13,500
#         </span>
#         Off on Exchange
#        </span>
#       </div>
#       <div class="_3MCpsc">
#        EMI starting from
#        <span class="_1JT2XE">
#         ₹
#         <!-- -->
#         632
#         <!-- -->
#         /month
#        </span>
#       </div>
#       <div class="OPF9v4 _2WQngC">
#        <span class="_1xZuAn">
#         Offers
#        </span>
#        <ul class="_3U7997">
#         <li class="_1ZRRx1">
#          Special Price
#         </li>
#         <li class="_1ZRRx1">
#          Bank Offer
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#    </a>
#   </div>
#  </div>
# </div>

# %%
container = containers[0]
print(container.div.img["alt"])

price = container.findAll("div",{"class": "col col-5-12 _2o7WAb"})
print(price[0].text)

ratings = container.findAll("div",{"class": "niH0FQ"})
print(ratings[0].text)
# Out:
# Apple iPhone SE (Space Grey, 32 GB)
# ₹18,999₹26,00026% offUp to ₹13,500 Off on ExchangeEMI starting from ₹632/monthOffersSpecial PriceBank Offer
# 4.4 ★44,107 Ratings & 6,495 Reviews

# %%
filename = "pro.csv"
f = open(filename, "w")

headers = "Product_Name,Pricing,Ratings\n"
f.write(headers)

for container in containers:
    product_name = container.div.img["alt"]

    price_container = container.findAll("div", {"class": "col col-5-12 _2o7WAb"})
    price = price_container[0].text.strip()

    rating_container = container.findAll("div", {"class": "niH0FQ"})
    rating = rating_container[0].text

    print("Product name:" + product_name)
    print("Price:" + price)
    print("rating:" + rating)
    trim_price = ''.join(price.split(','))
    rm_rupee = trim_price.split("₹")
    add_rs_price = "Rs." + rm_rupee[1]
    split_price = add_rs_price.split('E')
    final_price = split_price[0]

    split_rating = rating.split(" ")
    final_rating = split_rating[0]

    print(product_name.replace(",", "|") + "," + final_price + "," + final_rating + "\n")
    f.write(product_name.replace(",", "|") + "," + final_price + "," + final_rating + "\n")
    
f.close()
# Out:
# Product name:Apple iPhone SE (Space Grey, 32 GB)
# Price:₹18,999₹26,00026% offUp to ₹13,500 Off on ExchangeEMI starting from ₹632/monthOffersSpecial PriceBank Offer
# rating:4.4 ★44,107 Ratings & 6,495 Reviews
# Apple iPhone SE (Space Grey| 32 GB),Rs.18999,4.4
#
# Product name:Apple iPhone SE (Rose Gold, 32 GB)
# Price:₹18,999₹26,00026% offUp to ₹13,500 Off on ExchangeEMI starting from ₹632/monthOffersSpecial PriceBank Offer
# rating:4.4 ★44,107 Ratings & 6,495 Reviews
# Apple iPhone SE (Rose Gold| 32 GB),Rs.18999,4.4
#
# Product name:Apple iPhone XS Max (Gold, 64 GB)
# Price:₹1,09,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3651/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Gold| 64 GB),Rs.109900Up to ,4.9
#
# Product name:Apple iPhone XS Max (Gold, 256 GB)
# Price:₹1,24,900Up to ₹13,500 Off on ExchangeEMI starting from ₹4149/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Gold| 256 GB),Rs.124900Up to ,4.9
#
# Product name:Apple iPhone XS (Gold, 64 GB)
# Price:₹99,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3319/monthOffersBank Offer
# rating:4.9 ★25 Ratings & 0 Reviews
# Apple iPhone XS (Gold| 64 GB),Rs.99900Up to ,4.9
#
# Product name:Apple iPhone 6 (Space Grey, 32 GB)
# Price:₹24,999₹30,78018% offUp to ₹13,500 Off on ExchangeEMI starting from ₹831/monthOffersSpecial PriceBank Offer
# rating:4.4 ★49,380 Ratings & 5,776 Reviews
# Apple iPhone 6 (Space Grey| 32 GB),Rs.24999,4.4
#
# Product name:Apple iPhone XS (Space Grey, 256 GB)
# Price:₹1,14,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3817/monthOffersBank Offer
# rating:4.9 ★25 Ratings & 0 Reviews
# Apple iPhone XS (Space Grey| 256 GB),Rs.114900Up to ,4.9
#
# Product name:Apple iPhone 6 (Gold, 32 GB)
# Price:₹25,999₹30,78015% offUp to ₹13,500 Off on ExchangeEMI starting from ₹864/monthOffersSpecial PriceBank Offer
# rating:4.4 ★49,380 Ratings & 5,776 Reviews
# Apple iPhone 6 (Gold| 32 GB),Rs.25999,4.4
#
# Product name:Apple iPhone SE (Gold, 32 GB)
# Price:₹18,999₹26,00026% offUp to ₹13,500 Off on ExchangeEMI starting from ₹632/monthOffersSpecial PriceBank Offer
# rating:4.4 ★44,107 Ratings & 6,495 Reviews
# Apple iPhone SE (Gold| 32 GB),Rs.18999,4.4
#
# Product name:Apple iPhone 6s (Rose Gold, 32 GB)
# Price:₹32,999₹42,90023% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1097/monthOffersSpecial PriceBank Offer
# rating:4.4 ★8,018 Ratings & 929 Reviews
# Apple iPhone 6s (Rose Gold| 32 GB),Rs.32999,4.4
#
# Product name:Apple iPhone SE (Silver, 32 GB)
# Price:₹18,999₹26,00026% offUp to ₹13,500 Off on ExchangeEMI starting from ₹632/monthOffersSpecial PriceBank Offer
# rating:4.5 ★3,611 Ratings & 484 Reviews
# Apple iPhone SE (Silver| 32 GB),Rs.18999,4.5
#
# Product name:Apple iPhone XS Max (Space Grey, 256 GB)
# Price:₹1,24,900Up to ₹13,500 Off on ExchangeEMI starting from ₹4149/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Space Grey| 256 GB),Rs.124900Up to ,4.9
#
# Product name:Apple iPhone XS (Space Grey, 64 GB)
# Price:₹99,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3319/monthOffersBank Offer
# rating:4.9 ★25 Ratings & 0 Reviews
# Apple iPhone XS (Space Grey| 64 GB),Rs.99900Up to ,4.9
#
# Product name:Apple iPhone 7 (Jet Black, 32 GB)
# Price:₹46,999₹52,37010% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1562/monthOffersSpecial PriceBank Offer
# rating:4.5 ★21,382 Ratings & 2,642 Reviews
# Apple iPhone 7 (Jet Black| 32 GB),Rs.46999,4.5
#
# Product name:Apple iPhone 6s Plus (Space Grey, 32 GB)
# Price:₹39,999₹49,00018% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1329/monthOffersSpecial PriceBank Offer
# rating:4.5 ★1,646 Ratings & 245 Reviews
# Apple iPhone 6s Plus (Space Grey| 32 GB),Rs.39999,4.5
#
# Product name:Apple iPhone XS Max (Space Grey, 64 GB)
# Price:₹1,09,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3651/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Space Grey| 64 GB),Rs.109900Up to ,4.9
#
# Product name:Apple iPhone XS (Silver, 64 GB)
# Price:₹99,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3319/monthOffersBank Offer
# rating:4.9 ★25 Ratings & 0 Reviews
# Apple iPhone XS (Silver| 64 GB),Rs.99900Up to ,4.9
#
# Product name:Apple iPhone 7 (Black, 32 GB)
# Price:₹46,999₹52,37010% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1562/monthOffersSpecial PriceBank Offer
# rating:4.5 ★21,382 Ratings & 2,642 Reviews
# Apple iPhone 7 (Black| 32 GB),Rs.46999,4.5
#
# Product name:Apple iPhone XS Max (Silver, 64 GB)
# Price:₹1,09,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3651/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Silver| 64 GB),Rs.109900Up to ,4.9
#
# Product name:Apple iPhone XS Max (Silver, 256 GB)
# Price:₹1,24,900Up to ₹13,500 Off on ExchangeEMI starting from ₹4149/monthOffersBank Offer
# rating:4.9 ★58 Ratings & 14 Reviews
# Apple iPhone XS Max (Silver| 256 GB),Rs.124900Up to ,4.9
#
# Product name:Apple iPhone XS (Silver, 256 GB)
# Price:₹1,14,900Up to ₹13,500 Off on ExchangeEMI starting from ₹3817/monthOffersBank Offer
# rating:4.9 ★25 Ratings & 0 Reviews
# Apple iPhone XS (Silver| 256 GB),Rs.114900Up to ,4.9
#
# Product name:Apple iPhone 6s (Gold, 32 GB)
# Price:₹32,999₹42,90023% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1097/monthOffersSpecial PriceBank Offer
# rating:4.4 ★8,472 Ratings & 1,067 Reviews
# Apple iPhone 6s (Gold| 32 GB),Rs.32999,4.4
#
# Product name:Apple iPhone 7 (Rose Gold, 32 GB)
# Price:₹46,999₹52,37010% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1562/monthOffersSpecial PriceBank Offer
# rating:4.5 ★6,489 Ratings & 855 Reviews
# Apple iPhone 7 (Rose Gold| 32 GB),Rs.46999,4.5
#
# Product name:Apple iPhone 7 (Gold, 32 GB)
# Price:₹46,999₹52,37010% offUp to ₹13,500 Off on ExchangeEMI starting from ₹1562/monthOffersSpecial PriceBank Offer
# rating:4.5 ★5,311 Ratings & 757 Reviews
# Apple iPhone 7 (Gold| 32 GB),Rs.46999,4.5
